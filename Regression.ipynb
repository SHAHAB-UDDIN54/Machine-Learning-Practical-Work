# %% [markdown]
# <a href="https://colab.research.google.com/github/SHAHAB-UDDIN54/Machine-Learning-Practical-Work/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# create dataset

# %%
data = {
    "studyHours":[1,2,3,4,5,6],
    "Marks":[50,60,75,80,85,90]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    studyHours  Marks
# 0           1     50
# 1           2     60
# 2           3     75
# 3           4     80
# 4           5     85
# 5           6     90

# %% [markdown]
# features (x) and target(y)

# %%
x = df[["studyHours"]]
y = df["Marks"]

# %% [markdown]
# train test split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# train linear Regression  model

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# predication

# %%
y_perd = model.predict(x_test)
print("predicatel marks", y_perd)
print("acutal marks",y_test.values)
# Out:
# predicatel marks [65. 70.]
# acutal marks [50 60]

# %% [markdown]
# error (how good the model

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_perd)
print("mean squared error",mse)
# Out:
# mean squared error 162.5

# %% [markdown]
# visual intuition

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.plot(x,model.predict(x),color = "red")
plt.xlabel("study hours")
plt.ylabel("marks")
plt.title("Regression model")
plt.show()
