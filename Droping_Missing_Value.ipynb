# %% [markdown]
# <a href="https://colab.research.google.com/github/SHAHAB-UDDIN54/Machine-Learning-Practical-Work/blob/main/Droping_Missing_Value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_excel("/content/ml_practice_dataset 2.xlsx")
dataset.head(5)
# Out:
#     ID   Name   Age    Salary Department  Experience_Years    City  \
# 0  1.0  Julia  55.0  118556.0         HR              37.0  London
# 1  2.0  Grace   NaN  999999.0         IT               NaN     NaN
# 2  3.0    NaN   NaN  107660.0        NaN               NaN   Delhi
# 3  4.0  Julia  35.0       NaN         HR               NaN  Berlin
# 4  5.0  Alice   NaN  999999.0         HR               7.0  London
#
#   Performance  Joining_Year   Bonus
# 0         NaN        2011.0     NaN
# 1        Good        2022.0  6422.0
# 2         NaN        2011.0     NaN
# 3         NaN           NaN     NaN
# 4        Good        2014.0  8137.0

# %%
dataset.shape
# Out:
# (50, 10)

# %%
dataset.isnull().sum()
# Out:
# ID                   2
# Name                 6
# Age                 29
# Salary               4
# Department           5
# Experience_Years    24
# City                 3
# Performance         11
# Joining_Year         4
# Bonus               21
# dtype: int64

# %%
dataset.notnull().sum()
# Out:
# ID                  48
# Name                44
# Age                 21
# Salary              46
# Department          45
# Experience_Years    26
# City                47
# Performance         39
# Joining_Year        46
# Bonus               29
# dtype: int64

# %%
dataset.describe()
# Out:
#               ID        Age         Salary  Experience_Years  Joining_Year  \
# count  48.000000  21.000000      46.000000         26.000000     46.000000
# mean   24.770833  39.904762  514828.304348         18.653846   2011.673913
# std    15.184314  11.678633  470160.678234         13.460884      7.357700
# min     1.000000  20.000000   24114.000000          0.000000   2000.000000
# 25%    11.750000  33.000000   65575.250000          7.000000   2006.000000
# 50%    24.500000  37.000000  118221.500000         18.000000   2010.500000
# 75%    38.250000  52.000000  999999.000000         32.500000   2019.250000
# max    50.000000  60.000000  999999.000000         40.000000   2024.000000
#
#             Bonus
# count    29.00000
# mean   6053.62069
# std    2614.90895
# min     620.00000
# 25%    4389.00000
# 50%    6928.00000
# 75%    8137.00000
# max    9890.00000

# %%
dataset.shape[0]
# Out:
# 50

# %%
dataset.shape[1]
# Out:
# 10

# %%
dataset.dropna()
# Out:
#       ID     Name   Age    Salary Department  Experience_Years     City  \
# 19   5.0      Eva  33.0   35034.0         IT               4.0   Berlin
# 20  21.0      Eva  37.0  999999.0    Finance              20.0   London
# 27  28.0  Charlie  56.0   66053.0    Finance               0.0  Toronto
# 39  40.0    Julia  39.0   40502.0         HR              35.0   Berlin
# 46  47.0      Bob  57.0  999999.0      Sales              33.0  Toronto
# 49  50.0  Charlie  40.0  999999.0    Finance               3.0  Toronto
#
#    Performance  Joining_Year   Bonus
# 19     Average        2024.0  4939.0
# 20   Excellent        2021.0  5949.0
# 27     Average        2021.0  2232.0
# 39   Excellent        2022.0  4389.0
# 46   Excellent        2009.0  1271.0
# 49     Average        2009.0  9225.0

# %%
dataset.isnull().sum()
# Out:
# ID                   2
# Name                 6
# Age                 29
# Salary               4
# Department           5
# Experience_Years    24
# City                 3
# Performance         11
# Joining_Year         4
# Bonus               21
# dtype: int64

# %%
dataset.drop(columns=["Bonus"])
# Out:
# 0        NaN
# 1     6422.0
# 2        NaN
# 3        NaN
# 4     8137.0
# 5     8454.0
# 6     2540.0
# 7        NaN
# 8     4602.0
# 9        NaN
# 10       NaN
# 11    7360.0
# 12       NaN
# 13       NaN
# 14    7552.0
# 15    7017.0
# 16    8277.0
# 17    9890.0
# 18       NaN
# 19    4939.0
# 20    5949.0
# 21    3268.0
# 22       NaN
# 23       NaN
# 24    7338.0
# 25    6928.0
# 26    8812.0
# 27    2232.0
# 28       NaN
# 29    9349.0
# 30     620.0
# 31       NaN
# 32    5481.0
# 33       NaN
# 34       NaN
# 35    7707.0
# 36    7493.0
# 37       NaN
# 38    3048.0
# 39    4389.0
# 40       NaN
# 41    9169.0
# 42       NaN
# 43    4563.0
# 44    3523.0
# 45       NaN
# 46    1271.0
# 47       NaN
# 48       NaN
# 49    9225.0
# Name: Bonus, dtype: float64

# %%
dataset.isnull().sum()
# Out:
# ID                   2
# Name                 6
# Age                 29
# Salary               4
# Department           5
# Experience_Years    24
# City                 3
# Performance         11
# Joining_Year         4
# Bonus               21
# dtype: int64

# %%
dataset.dropna(inplace =True)

# %%
dataset.head(5)
# Out:
#       ID     Name   Age    Salary Department  Experience_Years     City  \
# 19   5.0      Eva  33.0   35034.0         IT               4.0   Berlin
# 20  21.0      Eva  37.0  999999.0    Finance              20.0   London
# 27  28.0  Charlie  56.0   66053.0    Finance               0.0  Toronto
# 39  40.0    Julia  39.0   40502.0         HR              35.0   Berlin
# 46  47.0      Bob  57.0  999999.0      Sales              33.0  Toronto
#
#    Performance  Joining_Year   Bonus
# 19     Average        2024.0  4939.0
# 20   Excellent        2021.0  5949.0
# 27     Average        2021.0  2232.0
# 39   Excellent        2022.0  4389.0
# 46   Excellent        2009.0  1271.0

# %%
sns.heatmap(dataset.isnull())
plt.show()
